# %% [markdown]
# <a href="https://colab.research.google.com/github/naman-tiwari/Customer-Support-on-Twitter/blob/main/customer_support_on_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/archive/sample.csv')

# %%
data.head()
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
# 4  @VirginTrains see attached error message. I've...            119243
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# 2                      NaN
# ...

# %%
data.sample(5)
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 8     119242        105836     True  Tue Oct 10 15:09:00 +0000 2017
# 9     119246  VirginTrains    False  Tue Oct 10 10:13:19 +0000 2017
# 22    119256        105840     True  Wed Oct 11 12:53:29 +0000 2017
# 69    119309        105855     True  Wed Oct 11 13:33:43 +0000 2017
#
#                                                  text response_tweet_id  \
# 1   @105835 Your business means a lot to us. Pleas...               NaN
# 8   @VirginTrains I still haven't heard &amp; the ...            119240
# 9   @105836 That's what we're here for Miriam 😊  T...            119242
# 22  @76495 @91226 Please help! Spotify Premium ski...            119254
# 69          @Tesco Maybe hire colleagues who can see?               NaN
#
#     in_response_to_tweet_id
# 1                  119239.0
# 8                  119246.0
# 9                  119247.0
# ...

# %%
data.tail(5)
# Out:
#     tweet_id author_id  inbound                      created_at  \
# 88    119330    105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331    105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332     Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333    105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335     Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 88  @105860 I wish Amazon had an option of where I...            119329
# 89  They reschedule my shit for tomorrow https://t...            119330
# 90  @105861 Hey Sara, sorry to hear of the issues ...            119333
# 91  @Tesco bit of both - finding the layout cumber...     119335,119336
# 92  @105861 If that doesn't help please DM your fu...               NaN
#
#     in_response_to_tweet_id
# 88                 119331.0
# 89                      NaN
# 90                 119334.0
# 91                 119332.0
# ...

# %%
data["text"][3]
# Out:
# '@105836 LiveChat is online at the moment - https://t.co/SY94VtU8Kq or contact 03331 031 031 option 1, 4, 3 (Leave a message) to request a call back'

# %%
data.head(4)
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# 2                      NaN
# 3                 119242.0

# %%
# prompt: Using dataframe data: remove url

import re
data['text'] = data['text'].apply(lambda x: re.sub(r'http\S+', '', x))

# %%
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
# prompt: Using dataframe data: print all the text from the above dataset

print(data['text'][6])
# Out:
# @VirginTrains yep, I've tried laptop too several times over the past week and again today. I've tried different browsers too

# %%
# prompt: remove all punctuation marks and @

import string

def remove_punctuation(text):
  for punctuation in string.punctuation:
    text = text.replace(punctuation, ' ')
  return text

data['text'] = data['text'].apply(lambda x: remove_punctuation(x))
data['text'] = data['text'].apply(lambda x: x.replace('@', ''))

data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0    AppleSupport causing the reply to be disregar...            119236
# ...

# %%
data['text'][3]
# Out:
# ' 105836 LiveChat is online at the moment    or contact 03331 031 031 option 1  4  3  Leave a message  to request a call back'

# %%
# prompt: remove unwarranted space from the above data

data['text'] = data['text'].apply(lambda x: ' '.join(x.split()))
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dd9328c3ea34> in <cell line: 3>()
#       1 # prompt: remove unwarranted space from the above data
#       2
# ----> 3 data['text'] = data['text'].apply(lambda x: ' '.join(x.split()))
#       4 data
#
# NameError: name 'data' is not defined

# %%
data['text'][5]
# Out:
# '105836 Have you tried from another device Miriam MM'

# %%
import textblob

# %%
from textblob import TextBlob

# %%
# prompt: correct all the spelling mistak\es in the above dataset

# !pip install autocorrect
from autocorrect import Speller
spell = Speller(lang="en")

def correct_spelling(text):
  corrected_text = []
  for word in text.split():
    corrected_text.append(spell(word))
  return " ".join(corrected_text)

data["text"] = data["text"].apply(lambda x: correct_spelling(x))
data
# Out:
# ...
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
data["text"][6]
# Out:
# "@VirginTrains yep, I've tried laptop too several times over the past week and again today. I've tried different browsers too"

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# !pip install emoji

# %%
import emoji

# %%
import re

# %%
data["text"][55]
# Out:
# "@105850 Once the points load and you hit the number, you get it immediately! You'll even receive a contrast email. Are you almost there? ^A"

# %%
data.head()
# Out:
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
# 4  @VirginTrains see attached error message. I've...            119243
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# 2                      NaN
# ...

# %%
def remove_emoji(text):
    clean_text=emoji.demojize(text)
    return clean_text

# %%
remove_emoji(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-ec19042f01eb> in <cell line: 1>()
# ----> 1 remove_emoji(text)
#
# NameError: name 'text' is not defined

# %%
import pandas as pd
import emoji

# Remove emoji from the text column
data["text"] = data["text"].apply(lambda x: emoji.demojize(x))

# Save the modified dataset
data.to_csv("your_dataset_without_emoji.csv", index=False)

# %%
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
# prompt: Using dataframe data: remove @ form the dataset

data['text'] = data['text'].str.replace('@', '')

# %%
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   AppleSupport causing the reply to be disregard...            119236
# ...

# %%
import re

def remove_digits(text):
  pattern = r'\b\d{5,6}\b'
  return re.sub(pattern, '', text)

data['text'] = data['text'].apply(lambda x: remove_digits(x))

# %%
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
# !pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 7.2 MB/s eta 0:00:00
# ...

# %%
data["text"][0]
# Out:
# '@AppleSupport causing the reply to be disregarded and the tapped notification under the keyboard is opened:enraged_face::enraged_face::enraged_face:'

# %%
import pandas as pd
import emoji

# Remove emoji from the text column
data["text"] = data["text"].apply(lambda x: emoji.demojize(x))

# %%
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 89    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 90    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 91    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
# 92    119335         Tesco    False  Wed Oct 11 15:38:07 +0000 2017
#
#                                                  text response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...            119236
# ...

# %%
# !git clone https://github.com/naman-tiwari/Customer-Support-on-Twitter.git
# Out:
# Cloning into 'Customer-Support-on-Twitter'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (14/14), 1.36 MiB | 14.77 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
cd Customer-Support-on-Twitter/
# Out:
# [Errno 2] No such file or directory: 'customer-Support-on-Twitter/'
# /content/Customer-Support-on-Twitter

# %%
# !git add .
# !git commit -m "removed emojis"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "namantiwariofficial23@gmail.com"

# %%
# !git config --global user.name "naman-tiwari"
